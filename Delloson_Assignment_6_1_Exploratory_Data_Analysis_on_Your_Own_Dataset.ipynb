# %%
import pandas as pd
filepath = '/content/healthcare_dataset.csv'
data = pd.read_csv(filepath)
data
# Out:
#                   Name  Age  Gender Blood Type Medical Condition  \
# 0        Bobby JacksOn   30    Male         B-            Cancer
# 1         LesLie TErRy   62    Male         A+           Obesity
# 2          DaNnY sMitH   76  Female         A-           Obesity
# 3         andrEw waTtS   28  Female         O+          Diabetes
# 4        adrIENNE bEll   43  Female        AB+            Cancer
# ...                ...  ...     ...        ...               ...
# 7237       JaMEs MCkAy   78    Male         A-      Hypertension
# 7238      CheLsEA roTh   45    Male         B+      Hypertension
# 7239   FeRNandO wILson   75    Male         A-         Arthritis
# 7240    jaMEs roBINSON   39  Female        AB+            Cancer
# 7241  jAniCe ZImMERMaN   38  Female        AB+            Asthma
#
#      Date of Admission            Doctor                    Hospital  \
# 0           31/01/2024     Matthew Smith             Sons and Miller
# ...

# %%
# Identify the column names
column = list(data.columns)
print(column)
# Out:
# ['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition', 'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider', 'Billing Amount', 'Room Number', 'Admission Type', 'Discharge Date', 'Medication', 'Test Results']

# %%
# Display the total number of records
TotalRec = len(data)
print(TotalRec)
# Out:
# 7242

# %%
# Display the first 20 records
first20 = data.head(20)
print(first20)
# Out:
#                    Name  Age  Gender Blood Type Medical Condition  \
# 0         Bobby JacksOn   30    Male         B-            Cancer
# 1          LesLie TErRy   62    Male         A+           Obesity
# 2           DaNnY sMitH   76  Female         A-           Obesity
# 3          andrEw waTtS   28  Female         O+          Diabetes
# 4         adrIENNE bEll   43  Female        AB+            Cancer
# 5         EMILY JOHNSOn   36    Male         A+            Asthma
# 6        edwArD EDWaRDs   21  Female        AB-          Diabetes
# 7    CHrisTInA MARtinez   20  Female         A+            Cancer
# 8       JASmINe aGuIlaR   82    Male        AB+            Asthma
# 9      ChRISTopher BerG   58  Female        AB-            Cancer
# 10     mIchElLe daniELs   72    Male         O+            Cancer
# 11       aaRon MARtiNeZ   38  Female         A-      Hypertension
# 12        connOR HANsEn   75  Female         A+          Diabetes
# ...

# %%
# Display the last 20 records
last20 = data.tail(20)
print(last20)
# Out:
#                       Name  Age  Gender Blood Type Medical Condition  \
# 7222          AdAM HoPkinS   58    Male         B-            Asthma
# 7223      cHRIsTiNA BARtoN   47    Male         B+         Arthritis
# 7224         joSEPH WrIGHt   55    Male         A+            Cancer
# 7225        NAtHan fleMinG   45  Female        AB+         Arthritis
# 7226      oScAR StRIckLand   50  Female         A+         Arthritis
# 7227        dAniel fIsChER   25  Female         A-           Obesity
# 7228          JimMy ArNOLd   55  Female         B+           Obesity
# 7229            HENrY RYAn   29  Female         B+           Obesity
# 7230         naTHAN cherRY   32  Female         B+           Obesity
# 7231       HAnnah MorRISon   56    Male         O-      Hypertension
# 7232        JENniFEr ADAMS   18    Male         B+          Diabetes
# 7233         CHERyl GUERra   43  Female         O-         Arthritis
# 7234          jOHN swAnson   64    Male         B-         Arthritis
# ...

# %%
#Change the Medication column to MedsForYou
data.rename(columns={'Medication': 'MedsForYou'}, inplace=True)
data
# Out:
#                   Name  Age  Gender Blood Type Medical Condition  \
# 0        Bobby JacksOn   30    Male         B-            Cancer
# 1         LesLie TErRy   62    Male         A+           Obesity
# 2          DaNnY sMitH   76  Female         A-           Obesity
# 3         andrEw waTtS   28  Female         O+          Diabetes
# 4        adrIENNE bEll   43  Female        AB+            Cancer
# ...                ...  ...     ...        ...               ...
# 7237       JaMEs MCkAy   78    Male         A-      Hypertension
# 7238      CheLsEA roTh   45    Male         B+      Hypertension
# 7239   FeRNandO wILson   75    Male         A-         Arthritis
# 7240    jaMEs roBINSON   39  Female        AB+            Cancer
# 7241  jAniCe ZImMERMaN   38  Female        AB+            Asthma
#
#      Date of Admission            Doctor                    Hospital  \
# 0           31/01/2024     Matthew Smith             Sons and Miller
# ...

# %%
# Delete Insurance Provider column
data = data.drop('Insurance Provider', axis = 1)
data
# Out:
#                   Name  Age  Gender Blood Type Medical Condition  \
# 0        Bobby JacksOn   30    Male         B-            Cancer
# 1         LesLie TErRy   62    Male         A+           Obesity
# 2          DaNnY sMitH   76  Female         A-           Obesity
# 3         andrEw waTtS   28  Female         O+          Diabetes
# 4        adrIENNE bEll   43  Female        AB+            Cancer
# ...                ...  ...     ...        ...               ...
# 7237       JaMEs MCkAy   78    Male         A-      Hypertension
# 7238      CheLsEA roTh   45    Male         B+      Hypertension
# 7239   FeRNandO wILson   75    Male         A-         Arthritis
# 7240    jaMEs roBINSON   39  Female        AB+            Cancer
# 7241  jAniCe ZImMERMaN   38  Female        AB+            Asthma
#
#      Date of Admission            Doctor                    Hospital  \
# 0           31/01/2024     Matthew Smith             Sons and Miller
# ...

# %%
# New column for Insurance Provider
data['Insurance Provider'] = data.apply(InsuranceProvider, axis=1)
data
# Out:
#                   Name  Age  Gender Blood Type Medical Condition  \
# 0        Bobby JacksOn   30    Male         B-            Cancer
# 1         LesLie TErRy   62    Male         A+           Obesity
# 2          DaNnY sMitH   76  Female         A-           Obesity
# 3         andrEw waTtS   28  Female         O+          Diabetes
# 4        adrIENNE bEll   43  Female        AB+            Cancer
# ...                ...  ...     ...        ...               ...
# 7237       JaMEs MCkAy   78    Male         A-      Hypertension
# 7238      CheLsEA roTh   45    Male         B+      Hypertension
# 7239   FeRNandO wILson   75    Male         A-         Arthritis
# 7240    jaMEs roBINSON   39  Female        AB+            Cancer
# 7241  jAniCe ZImMERMaN   38  Female        AB+            Asthma
#
#      Date of Admission            Doctor                    Hospital  \
# 0           31/01/2024     Matthew Smith             Sons and Miller
# ...

# %%
# Display the patients who has cancer
cancerPatients = data[data['Medical Condition'] == 'Cancer']
total = len(cancerPatients)

print(cancerPatients)
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# 7     CHrisTInA MARtinez   20  Female         A+            Cancer
# 9       ChRISTopher BerG   58  Female        AB-            Cancer
# 10      mIchElLe daniELs   72    Male         O+            Cancer
# ...                  ...  ...     ...        ...               ...
# 7216    josHua WIlkInson   68    Male         O+            Cancer
# 7217         wenDY foLey   31  Female         O+            Cancer
# 7219      cLaUdia SaNtOs   62    Male        AB+            Cancer
# 7224       joSEPH WrIGHt   55    Male         A+            Cancer
# 7240      jaMEs roBINSON   39  Female        AB+            Cancer
#
#      Date of Admission             Doctor                       Hospital  \
# 0           31/01/2024      Matthew Smith                Sons and Miller
# ...

# %%
# Display the Female patients
fPatients = data[data['Gender'] == 'Female']
total = len(fPatients)

print(fPatients)
# Out:
#                       Name  Age  Gender Blood Type Medical Condition  \
# 2              DaNnY sMitH   76  Female         A-           Obesity
# 3             andrEw waTtS   28  Female         O+          Diabetes
# 4            adrIENNE bEll   43  Female        AB+            Cancer
# 6           edwArD EDWaRDs   21  Female        AB-          Diabetes
# 7       CHrisTInA MARtinez   20  Female         A+            Cancer
# ...                    ...  ...     ...        ...               ...
# 7230         naTHAN cherRY   32  Female         B+           Obesity
# 7233         CHERyl GUERra   43  Female         O-         Arthritis
# 7235  chrisTOPHeR kINg DDS   80  Female         A-           Obesity
# 7240        jaMEs roBINSON   39  Female        AB+            Cancer
# 7241      jAniCe ZImMERMaN   38  Female        AB+            Asthma
#
#      Date of Admission            Doctor                         Hospital  \
# ...

# %%
# Use numpy to get the average, median, and standard deviation of the KDA
import numpy as np
avgKDA = np.mean(data['Billing Amount'])
medKDA = np.median(data['Billing Amount'])
stdKDA = np.std(data['Billing Amount'])

print("Average Billing Amount:",avgKDA)
print("Median Billing Amount:", medKDA)
print("Standard Deviation of Billing Amount:", stdKDA)
# Out:
# Average Billing Amount: 25615.333092902703
# Median Billing Amount: nan
# Standard Deviation of Billing Amount: 14181.283848878782
